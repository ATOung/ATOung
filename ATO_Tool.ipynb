# %%
#@title Mount GDrive
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# #Folder Location

# %%
Folder_Patch = "/content/gdrive/MyDrive/Test" #@param {type:"string"}
# %cd "$Folder_Patch"

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #GDrive Downloader

# %% [markdown]
# ##MEGA Downloader

# %%
#@title Install MEGA
# !apt-get -y update
# !apt-get install megatools

# %%
url_link = "https://mega.nz/#!ZdgwATIS!xRSlc7XkPvsArhCg-hkaToRpStMEe6TfrEO2RlbdXXI" #@param {type:"string"}
# !megadl "$url_link"

# %% [markdown]
# ##WGET

# %%
url_link1 = "https://download939.mediafire.com/w3a7ff8rr4cg/8lznzn95feoruyt/%5BAnimePlusMM%5D+%E1%80%96%E1%80%9A%E1%80%B9%E1%80%9B%E1%80%AE%E1%80%B1%E1%80%90%E1%80%B8+S2+-+31+%5BHEVC+1080p+10bit%5D.mp4" #@param {type:"string"}
url_link2 = "" #@param {type:"string"}
url_link3 = "" #@param {type:"string"}
url_link4 = "" #@param {type:"string"}
url_link5 = "" #@param {type:"string"}
# !wget "$url_link1"
# !wget "$url_link2"
# !wget "$url_link3"
# !wget "$url_link4"
# !wget "$url_link5"
# Out:
# --2021-08-01 06:15:53--  https://download939.mediafire.com/w3a7ff8rr4cg/8lznzn95feoruyt/%5BAnimePlusMM%5D+%E1%80%96%E1%80%9A%E1%80%B9%E1%80%9B%E1%80%AE%E1%80%B1%E1%80%90%E1%80%B8+S2+-+31+%5BHEVC+1080p+10bit%5D.mp4
# Resolving download939.mediafire.com (download939.mediafire.com)... 205.196.121.134
# Connecting to download939.mediafire.com (download939.mediafire.com)|205.196.121.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305840704 (292M) [video/mp4]
# Saving to: ‘[AnimePlusMM]+ဖယ္ရီေတး+S2+-+31+[HEVC+1080p+10bit].mp4’
#
# [AnimePlusMM]+ဖယ္ရီေတ 100%[===================>] 291.67M  24.1MB/s    in 11s
#
# 2021-08-01 06:16:04 (26.5 MB/s) - ‘[AnimePlusMM]+ဖယ္ရီေတး+S2+-+31+[HEVC+1080p+10bit].mp4’ saved [305840704/305840704]
#
# http://: Invalid host name.
# http://: Invalid host name.
# http://: Invalid host name.
# http://: Invalid host name.

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #Gdrive Tools

# %% [markdown]
# ##Copy

# %%
#@markdown *Input file will be copied into the destination folder.*
input_file_or_folder = "/content/gdrive/MyDrive/install.sh" #@param {type:"string"}
destination_folder = "/content/gdrive/MyDrive/Test" #@param {type:"string"}
# !cp -n -r -v "$input_file_or_folder" "$destination_folder"

# %% [markdown]
# ##Drive Check

# %%
Folder_Patch = "/content/gdrive/MyDrive/Test" #@param {type:"string"}
# !du -h '$Folder_Patch'
# Out:
# 4.0K	/content/gdrive/MyDrive/Test/.ipynb_checkpoints
# 822M	/content/gdrive/MyDrive/Test

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------
